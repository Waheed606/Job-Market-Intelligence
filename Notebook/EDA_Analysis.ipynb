# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ## Problems statement
# > The uers can enter the job role,experince level,expericence level ,years of experience and skills and show the responsiblitity in the job.

# %%
df=pd.read_csv('job_dataset.csv')

# %%
df.head()
# Out:
#        JobID           Title ExperienceLevel YearsOfExperience  \
# 0  NET-F-001  .NET Developer         Fresher               0-1
# 1  NET-F-002  .NET Developer         Fresher               0-1
# 2  NET-F-003  .NET Developer         Fresher               0-1
# 3  NET-F-004  .NET Developer         Fresher               0-1
# 4  NET-F-005  .NET Developer         Fresher               0-1
#
#                                               Skills  \
# 0  C#; VB.NET basics; .NET Framework; .NET Core f...
# 1  C#; .NET Framework basics; ASP.NET; Razor; HTM...
# 2  C#; VB.NET basics; .NET Core; ASP.NET MVC; HTM...
# 3  C#; .NET Framework; ASP.NET basics; SQL Server...
# 4  C#; ASP.NET; MVC; Entity Framework basics; SQL...
#
#                                     Responsibilities  \
# 0  Assist in coding and debugging applications; L...
# 1  Write simple C# programs under guidance; Suppo...
# 2  Contribute to development of small modules; As...
# ...

# %%
df.columns
# Out:
# Index(['JobID', 'Title', 'ExperienceLevel', 'YearsOfExperience', 'Skills',
#        'Responsibilities', 'Keywords'],
#       dtype='object')

# %% [markdown]
# >The target columns is Responsibilities that is text data

# %%
df.shape
# Out:
# (1068, 7)

# %% [markdown]
# >The dataset contain the 1068 row and 7 columns

# %%
cat_columns=df.select_dtypes(include='object').columns
print(cat_columns)
# Out:
# Index(['JobID', 'Title', 'ExperienceLevel', 'YearsOfExperience', 'Skills',
#        'Responsibilities', 'Keywords'],
#       dtype='object')

# %% [markdown]
# > In this dataset the most columns are categorical

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1068 entries, 0 to 1067
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   JobID              1068 non-null   object
#  1   Title              1067 non-null   object
#  2   ExperienceLevel    1068 non-null   object
#  3   YearsOfExperience  1068 non-null   object
#  4   Skills             1068 non-null   object
#  5   Responsibilities   1068 non-null   object
#  6   Keywords           1068 non-null   object
# dtypes: object(7)
# memory usage: 58.5+ KB

# %% [markdown]
# All the columns are in the correct data type except the experince level

# %% [markdown]
# ## Missing Value Analysis

# %%
df.isnull().sum()
# Out:
# JobID                0
# Title                1
# ExperienceLevel      0
# YearsOfExperience    0
# Skills               0
# Responsibilities     0
# Keywords             0
# dtype: int64

# %% [markdown]
# Their is one missing  value in the  title

# %% [markdown]
# ## duplicate value Analysis

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# > There is no duplicate value in the dataset

# %% [markdown]
# ## Distribution Analysis

# %%
df['Title'].value_counts().head(20)
# Out:
# Title
# .NET Developer                  20
# Business Analyst                20
# Copywriter                      20
# Data Engineer                   20
# Digital Marketing Specialist    20
# Ethical Hacker                  20
# Fintech Engineer                20
# Game Developer                  20
# Graphic Designer                20
# JavaScript Developer            20
# Java Developer                  20
# Marketing Specialist            20
# Market Research Analyst         20
# Operations Manager              20
# Product Designer                20
# Product Manager                 20
# Project Manager                 20
# Python Developer                20
# Robotics Engineer               20
# Sales Executive                 20
# Name: count, dtype: int64

# %%
df['Skills'].value_counts().head(20)
# Out:
# Skills
# Salesforce; HubSpot; Predictive Analytics; Lead Generation; Negotiation; Closing Techniques; Sales Automation; Social Selling; Data-driven Sales; Relationship Management                                                                                                                             6
# Technical Writing; Editing; Proofreading; Adobe FrameMaker; MadCap Flare; CMS; HTML/CSS/XML; AI Writing Tools; Version Control; Agile Documentation                                                                                                                                                   5
# Salesforce; HubSpot; Lead Generation; Negotiation; Closing Deals; Pipeline Management; Product Demos; Sales Forecasting; Social Selling; Time Management                                                                                                                                              5
# ...

# %% [markdown]
# >The skill features show the abilities that the someone can do.

# %%
df['ExperienceLevel'].value_counts()
# Out:
# ExperienceLevel
# Experienced         476
# Fresher             363
# Entry-Level          66
# Senior-Level         66
# Mid-Level            60
# Senior               15
# Lead                  7
# Junior                5
# Mid-level             5
# Mid-Senior Level      3
# Mid-Senior            2
# Name: count, dtype: int64

# %%
df['Keywords'].value_counts()
# Out:
# Keywords
# JavaScript; TypeScript; React; Node.js; Jest; Webpack; Redux; CI/CD; Docker                                                                                             15
# Product Strategy; Data-Driven Decisions; Roadmapping; Agile Leadership; Stakeholder Management; User-Centered Design; Growth Metrics; Cross-Functional Collaboration    15
# C++; C#; Unity; Unreal Engine; Game AI; Shader Programming; Multiplayer; Performance Optimization                                                                       15
# Unity; Unreal Engine; C#; ARKit; ARCore; 3D Graphics; Spatial Computing; Performance Optimization; Cross-Platform; Machine Learning                                     15
# Ethical Hacking; Penetration Testing; Network Security; Python; Linux; Windows Security; Metasploit; Burp Suite; Cryptography; Malware Analysis                         14
# ...

# %% [markdown]
# >The keywords feature contain the techical specialization

# %% [markdown]
# >The distribution of the class is mostly imbalance

# %% [markdown]
# > There is no numerice feartures to contain  outliers

# %% [markdown]
# > their is no numeric feature for checking correlation

# %% [markdown]
# ## Final understanding of EDA

# %% [markdown]
# >1 the feature can be convert in the lowercase.
#
# >2 the skill feature contain a lot of information and the keywords contain the technical specilization and we keep the keyword and remove the skill columns because on the keywords feature we decide the skill.
#
#
#
# >3 The experince level is a text features it can be numerical features using one hot encoding.
#
# >4 The target feature is text and it cannot be convert into the vector form keep as same.
#
# >5 The Year of Experience contain information is similar to experience level and the year of experience can be remove .
#
# >6 The keywords contain the list of technical tool and it can be convert in the separate binary feature,and it can into different feature because the some job role contain the same feature.
